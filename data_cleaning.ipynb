# %%
import pandas as pd

# %%
pokemon_df = pd.read_csv('pokemonscraper\pokemon.csv', sep=',')
#oldpokemon_df = pd.read_csv('pokemonscraper\pokemon_old.csv', sep=',')

# %%
pokemon_df.head()
# Out:
#    Pokedex Number Base Pokemon   Variant Name  Type 1  Type 2  Total  HP  \
# 0              15     Beedrill       Beedrill     Bug  Poison    395  65
# 1              15     Beedrill  Mega Beedrill     Bug  Poison    495  65
# 2               1    Bulbasaur      Bulbasaur   Grass  Poison    318  45
# 3              21      Spearow        Spearow  Normal  Flying    262  40
# 4              16       Pidgey         Pidgey  Normal  Flying    251  40
#
#    Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 0      90       40       45  ...     75           1  False    False
# 1     150       40       15  ...    145           1   True    False
# 2      49       49       65  ...     45           1  False    False
# 3      60       30       31  ...     70           1  False    False
# 4      45       40       35  ...     56           1  False    False
#
#    Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# ...

# %%
pokemon_df.count()
# Out:
# Pokedex Number      1173
# Base Pokemon        1173
# Variant Name        1173
# Type 1              1173
# Type 2               637
# Total               1173
# HP                  1173
# Attack              1173
# Defense             1173
# Sp. Atk             1173
# Sp. Def             1173
# Speed               1173
# Generation          1173
# Mega                1173
# Paradox             1173
# Legendary           1173
# Pseudo-legendary    1173
# Ultrabeast          1173
# Regional Form       1173
# Mythical            1173
# img_name            1173
# dtype: int64

# %% [markdown]
# 1010 unique values for Pokedex number is expected

# %%
pokemon_df['Pokedex Number'].nunique()
# Out:
# 1010

# %% [markdown]
# The entries for the following pokemon need to be corrected:
#  - Pikachu
#  - Darmanitan
#  - Pumpkaboo
#  - Gourgeist

# %%
pokemon_df[pokemon_df['Pokedex Number']==25]
pik1 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Cosplay Pikachu'].index[0]
pik2 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Pikachu in a cap'].index[0]
pik3 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Partner Pikachu'].index[0]
print(pik1)
# Out:
# 1169

# %%
pik1 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Pikachu'].index[0]
pik2 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Pikachu in a cap'].index[0]
pik3 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Partner Pikachu'].index[0]
pokemon_df[pokemon_df['Pokedex Number']==25].drop([pokemon_df.index[pik1], pokemon_df.index[pik2], pokemon_df.index[pik3]]).replace(['Cosplay Pikachu'], 'Pikachu').replace(['0025_Cosplay Pikachu.png'], '0025_Pikachu.png')
# Out:
#       Pokedex Number Base Pokemon Variant Name    Type 1  Type 2  Total  HP  \
# 1169              25      Pikachu      Pikachu  Electric     NaN    320  35
#
#       Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 1169      55       40       50  ...     90           1  False    False
#
#       Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# 1169      False             False       False          False     False
#
#               img_name
# 1169  0025_Pikachu.png
#
# [1 rows x 21 columns]

# %%
pokemon_df = pokemon_df.drop([pokemon_df.index[pik1], pokemon_df.index[pik2], pokemon_df.index[pik3]])
pik = pokemon_df.loc[pokemon_df['Variant Name'] == 'Cosplay Pikachu'].index[0]
pokemon_df.loc[[pik], ['Variant Name']]=['Pikachu']
pokemon_df.loc[[pik], ['img_name']]=['0025_Pikachu.png']

# %%
pokemon_df[pokemon_df['Pokedex Number']==25]
# Out:
#       Pokedex Number Base Pokemon Variant Name    Type 1 Type 2  Total  HP  \
# 1169              25      Pikachu      Pikachu  Electric    NaN    320  35
#
#       Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 1169      55       40       50  ...     90           1  False    False
#
#       Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# 1169      False             False       False          False     False
#
#               img_name
# 1169  0025_Pikachu.png
#
# [1 rows x 21 columns]

# %% [markdown]
# Pikachu entry corrected and removed extra entries

# %%
pokemon_df[pokemon_df['Pokedex Number']==555]
# Out:
#      Pokedex Number Base Pokemon                       Variant Name Type 1  \
# 539             555   Darmanitan           Darmanitan Standard Mode   Fire
# 540             555   Darmanitan  Darmanitan Galarian Standard Mode    Ice
# 541             555   Darmanitan                Darmanitan Zen Mode   Fire
# 542             555   Darmanitan       Darmanitan Galarian Zen Mode    Ice
#
#       Type 2  Total   HP  Attack  Defense  Sp. Atk  ...  Speed  Generation  \
# 539      NaN    480  105     140       55       30  ...     95           5
# 540      NaN    540  105      30      105      140  ...     55           5
# 541  Psychic    540  105     160       55       30  ...    135           5
# 542     Fire    480  105     140       55       30  ...     95           5
#
#       Mega  Paradox  Legendary  Pseudo-legendary  Ultrabeast  Regional Form  \
# 539  False    False      False             False       False          False
# ...

# %%
dar1 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Darmanitan Galarian Standard Mode'].index[0]
dar2 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Darmanitan Galarian Zen Mode'].index[0]
dar3 = pokemon_df.loc[pokemon_df['Variant Name'] == 'Darmanitan Zen Mode'].index[0]
pokemon_df.loc[[dar1], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[480, 105, 140, 55, 30, 55, 95]
pokemon_df.loc[[dar2], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[540, 105, 160, 55, 30, 55, 135]
pokemon_df.loc[[dar3], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[540, 105, 30, 105, 140, 105, 55]

# %%
pokemon_df[pokemon_df['Pokedex Number']==555]
# Out:
#      Pokedex Number Base Pokemon                       Variant Name Type 1  \
# 539             555   Darmanitan           Darmanitan Standard Mode   Fire
# 540             555   Darmanitan  Darmanitan Galarian Standard Mode    Ice
# 541             555   Darmanitan                Darmanitan Zen Mode   Fire
# 542             555   Darmanitan       Darmanitan Galarian Zen Mode    Ice
#
#       Type 2  Total   HP  Attack  Defense  Sp. Atk  ...  Speed  Generation  \
# 539      NaN    480  105     140       55       30  ...     95           5
# 540      NaN    480  105     140       55       30  ...     95           5
# 541  Psychic    540  105      30      105      140  ...     55           5
# 542     Fire    540  105     160       55       30  ...    135           5
#
#       Mega  Paradox  Legendary  Pseudo-legendary  Ultrabeast  Regional Form  \
# 539  False    False      False             False       False          False
# ...

# %% [markdown]
# Darmanitan entries have been corrected and now the missing sizes for Gourgeist and Pumpkaboo will be added and corrected

# %%
gourgeist = pokemon_df.loc[pokemon_df['Variant Name'] == 'Gourgeist Super Size'].index[0]
pokemon_df.loc[[gourgeist], ['Variant Name']]=['Gourgeist Average Size']
missing_sizes = {
    'Pokedex Number': [711, 711, 711],
    'Base Pokemon': ['Gourgeist', 'Gourgeist', 'Gourgeist'],
    'Variant Name': ['Gourgeist Small Size', 'Gourgeist Large Size', 'Gourgeist Super Size'],
    'Type 1': ['Ghost', 'Ghost', 'Ghost'],
    'Type 2': ['Grass', 'Grass', 'Grass'],
    'Total': [494, 494, 494],
    'HP': [55, 75, 85],
    'Attack': [85, 95, 100],
    'Defense': [122, 122, 122],
    'Sp. Atk': [58, 58, 58],
    'Sp. Def': [75, 75, 75],
    'Speed': [99, 69, 54],
    'Generation': [6, 6, 6],
    'Mega': [False, False, False],
    'Paradox': [False, False, False],
    'Legendary': [False, False, False],
    'Pseudo-legendary': [False, False, False],
    'Ultrabeast': [False, False, False],
    'Regional Form': [False, False, False],
    'Mythical': [False, False, False],
    'img_name': ['0711_Gourgeist Super Size.png', '0711_Gourgeist Super Size.png', '0711_Gourgeist Super Size.png']
}
missing_df = pd.DataFrame(missing_sizes)
pokemon_df = pd.concat([pokemon_df, missing_df], axis=0)

# %%
pokemon_df[pokemon_df['Pokedex Number']==711]
# Out:
#      Pokedex Number Base Pokemon            Variant Name Type 1 Type 2  Total  \
# 366             711    Gourgeist  Gourgeist Average Size  Ghost  Grass    494
# 0               711    Gourgeist    Gourgeist Small Size  Ghost  Grass    494
# 1               711    Gourgeist    Gourgeist Large Size  Ghost  Grass    494
# 2               711    Gourgeist    Gourgeist Super Size  Ghost  Grass    494
#
#      HP  Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 366  65      90      122       58  ...     84           6  False    False
# 0    55      85      122       58  ...     99           6  False    False
# 1    75      95      122       58  ...     69           6  False    False
# 2    85     100      122       58  ...     54           6  False    False
#
#      Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# 366      False             False       False          False     False
# ...

# %% [markdown]
# Gourgeist now corrected

# %%
pumpkaboo = pokemon_df.loc[pokemon_df['Variant Name'] == 'Pumpkaboo Super Size'].index[0]
pokemon_df.loc[[pumpkaboo], ['Variant Name']]=['Pumpkaboo Average Size']
missing_sizes = {
    'Pokedex Number': [710, 710, 710],
    'Base Pokemon': ['Pumpkaboo', 'Pumpkaboo', 'Pumpkaboo'],
    'Variant Name': ['Pumpkaboo Small Size', 'Pumpkaboo Large Size', 'Pumpkaboo Super Size'],
    'Type 1': ['Ghost', 'Ghost', 'Ghost'],
    'Type 2': ['Grass', 'Grass', 'Grass'],
    'Total': [335, 335, 335],
    'HP': [44, 54, 59],
    'Attack': [66, 66, 66],
    'Defense': [70, 70, 70],
    'Sp. Atk': [44, 44, 44],
    'Sp. Def': [55, 55, 55],
    'Speed': [56, 46, 41],
    'Generation': [6, 6, 6],
    'Mega': [False, False, False],
    'Paradox': [False, False, False],
    'Legendary': [False, False, False],
    'Pseudo-legendary': [False, False, False],
    'Ultrabeast': [False, False, False],
    'Regional Form': [False, False, False],
    'Mythical': [False, False, False],
    'img_name': ['0710_Pumpkaboo Super Size.png', '0710_Pumpkaboo Super Size.png', '0710_Pumpkaboo Super Size.png']
}
missing_df = pd.DataFrame(missing_sizes)
pokemon_df = pd.concat([pokemon_df, missing_df], axis=0)

# %%
pokemon_df[pokemon_df['Pokedex Number']==710]
# Out:
#      Pokedex Number Base Pokemon            Variant Name Type 1 Type 2  Total  \
# 367             710    Pumpkaboo  Pumpkaboo Average Size  Ghost  Grass    335
# 0               710    Pumpkaboo    Pumpkaboo Small Size  Ghost  Grass    335
# 1               710    Pumpkaboo    Pumpkaboo Large Size  Ghost  Grass    335
# 2               710    Pumpkaboo    Pumpkaboo Super Size  Ghost  Grass    335
#
#      HP  Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 367  49      66       70       44  ...     51           6  False    False
# 0    44      66       70       44  ...     56           6  False    False
# 1    54      66       70       44  ...     46           6  False    False
# 2    59      66       70       44  ...     41           6  False    False
#
#      Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# 367      False             False       False          False     False
# ...

# %% [markdown]
# Pumpkaboo now corrected

# %%
pokemon_df[pokemon_df['Pokedex Number']==479]
fan = pokemon_df.loc[pokemon_df['Variant Name'] == 'Fan Rotom'].index[0]
pokemon_df.loc[[fan], ['Type 2']]=['Flying']

# %%
pokemon_df[pokemon_df['Pokedex Number']==479]
# Out:
#      Pokedex Number Base Pokemon Variant Name    Type 1  Type 2  Total  HP  \
# 626             479        Rotom        Rotom  Electric   Ghost    440  50
# 627             479        Rotom   Heat Rotom  Electric    Fire    520  50
# 628             479        Rotom   Wash Rotom  Electric   Water    520  50
# 629             479        Rotom  Frost Rotom  Electric     Ice    520  50
# 630             479        Rotom    Mow Rotom  Electric   Grass    520  50
# 631             479        Rotom    Fan Rotom  Electric  Flying    520  50
#
#      Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 626      50       77       95  ...     91           4  False    False
# 627      65      107      105  ...     86           4  False    False
# 628      65      107      105  ...     86           4  False    False
# 629      65      107      105  ...     86           4  False    False
# 630      65      107      105  ...     86           4  False    False
# ...

# %%
#pokemon_df.iloc[[635], ['Variant Name', 'Type 2', 'img_name']] =['Mow Rotom', 'Grass', '0479_Mow Rotom.png']
mow = pokemon_df.loc[(pokemon_df['Variant Name'] == 'Frost Rotom') & (pokemon_df['Type 2'] == 'Flying')].index[0]
pokemon_df.loc[[mow], ['Variant Name', 'Type 2', 'img_name']] =['Mow Rotom', 'Grass', '0479_Mow Rotom.png']

# %%
pokemon_df = pokemon_df.sort_values(by=['Pokedex Number', 'Total'], ascending=True)

# %%
#filter = pokemon_df['Group'].apply(lambda x: 'Regional Form' in x)
pokemon_df.head()
# Out:
#     Pokedex Number Base Pokemon   Variant Name Type 1  Type 2  Total  HP  \
# 2                1    Bulbasaur      Bulbasaur  Grass  Poison    318  45
# 26               2      Ivysaur        Ivysaur  Grass  Poison    405  60
# 24               3     Venusaur       Venusaur  Grass  Poison    525  80
# 25               3     Venusaur  Mega Venusaur  Grass  Poison    625  80
# 30               4   Charmander     Charmander   Fire     NaN    309  39
#
#     Attack  Defense  Sp. Atk  ...  Speed  Generation   Mega  Paradox  \
# 2       49       49       65  ...     45           1  False    False
# 26      62       63       80  ...     60           1  False    False
# 24      82       83      100  ...     80           1  False    False
# 25     100      123      122  ...     80           1   True    False
# 30      52       43       60  ...     65           1  False    False
#
#     Legendary  Pseudo-legendary  Ultrabeast  Regional Form  Mythical  \
# ...

# %%
pokemon_df.to_csv('pokemon_cleaned.csv', index=False)
