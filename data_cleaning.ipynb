# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pokemon_df = pd.read_csv('pokemonscraper\pokemon.csv', sep=',')

# %% [markdown]
# 1010 unique values for Pokedex number is expected

# %%
pokemon_df['Pokedex Number'].nunique()
# Out:
# 1

# %%
pokemon_df[pokemon_df['Pokedex Number']==25]
# Out:
#       Pokedex Number           Pokemon    Type 1 Type 2  Total  HP  Attack
# 1139              25           Pikachu  Electric    NaN    300  35      55  \
# 1140              25   Cosplay Pikachu  Electric    NaN    320  35      55
# 1141              25  Pikachu in a cap  Electric    NaN    300  35      55
# 1142              25   Partner Pikachu  Electric    NaN    320  35      55
#
#       Defense  Sp. Atk  Sp. Def  Speed  Generation     Group
# 1139       30       50       40     90           1  Standard
# 1140       40       50       50     90           1  Standard
# 1141       30       50       40     90           1  Standard
# 1142       40       50       50     90           1  Standard

# %% [markdown]
# These entries need to be corrected

# %%
pokemon_df[pokemon_df['Pokedex Number']==33]
# Out:
# Empty DataFrame
# Columns: [Pokedex Number, Pokemon, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Group]
# Index: []

# %%
pokemon_df[pokemon_df['Pokedex Number']==25].drop([pokemon_df.index[1141], pokemon_df.index[1142], pokemon_df.index[1139]]).replace(['Cosplay Pikachu'], 'Pikachu')
# Out:
#       Pokedex Number  Pokemon    Type 1  Type 2  Total  HP  Attack  Defense
# 1140              25  Pikachu  Electric     NaN    320  35      55       40  \
#
#       Sp. Atk  Sp. Def  Speed  Generation     Group
# 1140       50       50     90           1  Standard

# %%
pokemon_df[pokemon_df['Pokedex Number']==555]
# Out:
#      Pokedex Number                            Pokemon Type 1   Type 2  Total
# 503             555           Darmanitan Standard Mode   Fire      NaN    480  \
# 504             555  Darmanitan Galarian Standard Mode    Ice      NaN    480
# 505             555                Darmanitan Zen Mode   Fire  Psychic    540
# 506             555       Darmanitan Galarian Zen Mode    Ice     Fire    540
#
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation          Group
# 503  105     140       55       30       55     95           5       Standard
# 504  105     140       55       30       55     95           5  Regional Form
# 505  105      30      105      140      105     55           5       Standard
# 506  105     160       55       30       55    135           5  Regional Form

# %%
pokemon_df = pokemon_df[pokemon_df['Pokedex Number']==25].drop([pokemon_df.index[1141], pokemon_df.index[1142], pokemon_df.index[1139]]).replace(['Cosplay Pikachu'], 'Pikachu')

# %%
dar1 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Galarian Standard Mode'].index[0]
dar2 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Galarian Zen Mode'].index[0]
dar3 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Zen Mode'].index[0]
pokemon_df.loc[[dar1], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[480, 105, 140, 55, 30, 55, 95]
pokemon_df.loc[[dar2], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[540, 105, 160, 55, 30, 55, 135]
pokemon_df.loc[[dar3], ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]=[540, 105, 30, 105, 140, 105, 55]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dar1 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Galarian Standard Mode'].index[0]
#       2 dar2 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Galarian Zen Mode'].index[0]
#       3 dar3 = pokemon_df.loc[pokemon_df['Pokemon'] == 'Darmanitan Zen Mode'].index[0]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:5174, in Index.__getitem__(self, key)
#    5171 if is_integer(key) or is_float(key):
#    5172     # GH#44051 exclude bool, which would return a 2d ndarray
#    5173     key = com.cast_scalar_indexer(key)
# -> 5174     return getitem(key)
#    5176 if isinstance(key, slice):
#    5177     # This case is separated from the conditional above to avoid
#    5178     # pessimization com.is_bool_indexer and ndim checks.
#    5179     result = getitem(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pokemon_df[pokemon_df['Pokedex Number']==669]
# Out:
#      Pokedex Number  Pokemon Type 1 Type 2  Total  HP  Attack  Defense
# 377             669  Flabébé  Fairy    NaN    303  44      38       39  \
#
#      Sp. Atk  Sp. Def  Speed  Generation     Group
# 377       61       79     42           6  Standard

# %%
pokemon_df.sort_values(by=['Pokedex Number', 'Total'], ascending=True)
# Out:
#       Pokedex Number                 Pokemon    Type 1    Type 2  Total   HP
# 0                  1               Bulbasaur     Grass    Poison    318   45  \
# 1173               2                 Ivysaur     Grass    Poison    405   60
# 1171               3                Venusaur     Grass    Poison    525   80
# 1172               3           Mega Venusaur     Grass    Poison    625   80
# 1170               4              Charmander      Fire       NaN    309   39
# ...              ...                     ...       ...       ...    ...  ...
# 9               1006            Iron Valiant     Fairy  Fighting    590   74
# 8               1007     Koraidon Apex Build  Fighting    Dragon    670  100
# 7               1008  Miraidon Ultimate Mode  Electric    Dragon    670  100
# 6               1009            Walking Wake     Water    Dragon    590   99
# 5               1010             Iron Leaves     Grass   Psychic    590   90
#
#       Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation              Group
# 0         49       49       65       65     45           1           Standard
# 1173      62       63       80       80     60           1           Standard
# 1171      82       83      100      100     80           1           Standard
# 1172     100      123      122      120     80           1               Mega
# 1170      52       43       60       50     65           1           Standard
# ...      ...      ...      ...      ...    ...         ...                ...
# 9        130       90      120       60    116           9            Paradox
# 8        135      115       85      100    135           9  Legendary,Paradox
# 7         85      100      135      115    135           9  Legendary,Paradox
# 6         83       91      125       83    109           9            Paradox
# 5        130       88       70      108    104           9            Paradox
#
# [1174 rows x 13 columns]

# %%
pokemon_df.to_csv('pokemon_cleaned.csv')
# Out:
# 504
